# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from main import backtest
from hello import hypothesis_test
import numpy as np

# %% [markdown]
# # Naive Pairs Trader
#
# Bad, stupid, doesn't work. May as well toss into the garbage.
#
# Assumptions:
# Stationary and Cointegrated forever (Lmao no)
# Mean and Variance stable (Also no lmao)
# Closing price only
# No slippage
#
# Useful to demonstrate concept, but not much else.

# %% [markdown]
# # BTC and ETH Pair
# - 5 year period

# %%
data = hypothesis_test(["BTC-USD", "ETH-USD"],train_i = 10, years = 10, h = 0.05, K = 5, lam = 0.95)
data.plot()
plt.show()
# Out:
# Regime Changes: 44
# /Users/sjegoh/Documents/GitHub/algo_trade/venv_algotrade/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)

# %%
data = backtest(["BTC-USD", "ETH-USD"],years = 5, h = 0.05, K = 5, z_entry = 3, z_exit = 0.75, lam = 0.99)
data.plot()
plt.show()
# Out:
# Sharpe Ratio: 2.148955740307754

# %% [markdown]
# # Gold and Silver Pair
# - 10 year period

# %%
data = hypothesis_test(["GLD", "SLV"],train_i = 10, years = 10, h = 0.005, K = 1, lam = 0.999)
data.plot()
plt.show()
# Out:
# Regime Changes: 10
# /Users/sjegoh/Documents/GitHub/algo_trade/venv_algotrade/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)

# %%
data = backtest(["GLD", "SLV"],years = 10, h = 0.005, K = 1, z_entry = 10, z_exit = 0.75, lam = 0.999)
data.plot()
plt.show()
# Out:
# Sharpe Ratio: 3.26209940318509

# %% [markdown]
# # Chevron and Exxonmobile
# - 10 year period

# %%
data = hypothesis_test(["CVX", "XOM"],train_i = 10, years = 10, h = 0.1, K = 3, lam = 0.99)
data.plot()
plt.show()
# Out:
# Regime Changes: 63
# /Users/sjegoh/Documents/GitHub/algo_trade/venv_algotrade/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)

# %%
data = backtest(["CVX", "XOM"],years = 10, h = 0.1, K = 3, z_entry = 3, z_exit = 0.75, lam = 0.99)
data.plot()
plt.show()
# Out:
# Sharpe Ratio: 3.016517741171621

# %% [markdown]
# # NVDA and AMD Pair
# - 15 year period

# %%
data = hypothesis_test(["NVDA", "AMD"],train_i = 10, years = 15, h = 0.003, K = 25, lam = 0.99)
data.plot()
plt.show()
# Out:
# Regime Changes: 19
# /Users/sjegoh/Documents/GitHub/algo_trade/venv_algotrade/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)

# %%
data = backtest(["NVDA", "AMD"],years = 15, h = 0.003, K = 25, z_entry = 5, z_exit = 0.75, lam = 0.99)
data.plot()
plt.show()
# Out:
# Sharpe Ratio: 2.202041656186818

# %% [markdown]
# # Natural Gas Futures and Crude Oil Futures Pair
# - 15 year period

# %%
data = hypothesis_test(["NG=F", "CL=F"],train_i = 10, years = 15, h = 0.05, K = 2, lam = 0.99)
data.plot()
plt.show()
# Out:
# Regime Changes: 44
# /Users/sjegoh/Documents/GitHub/algo_trade/venv_algotrade/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)

# %%
data = backtest(["NG=F", "CL=F"],years = 15, h = 0.05, K = 2, z_entry = 5, z_exit = 0.75, lam = 0.99)
data.plot()
plt.show()
# Out:
# Sharpe Ratio: 2.118186551426397

# %% [markdown]
# # Regime tracking using Bayesian Online Changepoint Detection

# %% [markdown]
# #
