# %% [markdown]
# # Results (Ran on 7th December)

# %%
import matplotlib.pyplot as plt
from main import backtest
from hello import hypothesis_test

# %% [markdown]
# # Naive Pairs Trader
#
# Bad, stupid, doesn't work. May as well toss into the garbage.
#
# Assumptions:
# Stationary and Cointegrated forever (Lmao no)
# Mean and Variance stable (Also no lmao)
# Closing price only
# No slippage
#
# Useful to demonstrate concept, but not much else.

# %% [markdown]
# # BTC and ETH Pair
# - 5 year period

# %%
data = hypothesis_test(["BTC-USD", "ETH-USD"],train_i = 10, years = 5, h = 0.06, K = 5, lam = 0.95)
data.plot()
plt.show()
# Out:
# Regime Changes: 42
# /Users/sjegoh/Documents/GitHub/algo_trade/venv_algotrade/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)

# %%
data = backtest(["BTC-USD", "ETH-USD"],years = 5, h = 0.06, K = 5, z_entry = 3, z_exit = 0.75, lam = 0.99)
data.plot()
plt.show()
# Out:
# Sharpe Ratio: 2.688080343230018

# %% [markdown]
# # Gold and Silver Pair
# - 10 year period

# %%
data = hypothesis_test(["GLD", "SLV"],train_i = 10, years = 10, h = 0.005, K = 1, lam = 0.999)
data.plot()
plt.show()
# Out:
# Regime Changes: 10
# /Users/sjegoh/Documents/GitHub/algo_trade/venv_algotrade/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)

# %%
data = backtest(["GLD", "SLV"],years = 10, h = 0.005, K = 1, z_entry = 10, z_exit = 0.75, lam = 0.999)
data.plot()
plt.show()
# Out:
# Sharpe Ratio: 3.269960790472928

# %% [markdown]
# # Chevron and Exxonmobile
# - 10 year period

# %%
data = hypothesis_test(["CVX", "XOM"],train_i = 10, years = 10, h = 0.1, K = 3, lam = 0.99)
data.plot()
plt.show()
# Out:
# Regime Changes: 63
# /Users/sjegoh/Documents/GitHub/algo_trade/venv_algotrade/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)

# %%
data = backtest(["CVX", "XOM"],years = 10, h = 0.1, K = 3, z_entry = 3, z_exit = 0.75, lam = 0.99)
data.plot()
plt.show()
# Out:
# Sharpe Ratio: 2.984059013063942

# %% [markdown]
# # NVDA and AMD Pair
# - 15 year period

# %%
data = hypothesis_test(["NVDA", "AMD"],train_i = 10, years = 15, h = 0.003, K = 20, lam = 0.99)
data.plot()
plt.show()
# Out:
# Regime Changes: 13
# /Users/sjegoh/Documents/GitHub/algo_trade/venv_algotrade/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)

# %%
data = backtest(["NVDA", "AMD"],years = 15, h = 0.003, K = 20, z_entry = 5, z_exit = 0.75, lam = 0.99)
data.plot()
plt.show()
# Out:
# Sharpe Ratio: 2.489503272518585

# %% [markdown]
# # Natural Gas Futures and Crude Oil Futures Pair
# - 15 year period

# %%
data = hypothesis_test(["NG=F", "CL=F"],train_i = 10, years = 15, h = 0.1, K = 5, lam = 0.99)
data.plot()
plt.show()
# Out:
# Regime Changes: 71
# /Users/sjegoh/Documents/GitHub/algo_trade/venv_algotrade/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)

# %%
data = backtest(["NG=F", "CL=F"],years = 15, h = 0.05, K = 2, z_entry = 3, z_exit = 0.75, lam = 0.99)
data.plot()
plt.show()
# Out:
# Sharpe Ratio: 1.2118914684676905

# %% [markdown]
# # Regime tracking using Bayesian Online Changepoint Detection

# %% [markdown]
# #
